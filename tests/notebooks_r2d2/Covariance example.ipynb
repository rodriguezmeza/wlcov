# %%
import AnalyticalCov as cov # Code to pass from C to Pyhton 
import numpy as np
import matplotlib.pyplot as plt

# %%
thtdata = np.array([0.00232712, 0.00275673, 0.00326565, 0.00386852, 0.00458269,
       0.00542871, 0.00643091, 0.00761812, 0.00902451, 0.01069053,
       0.01266412, 0.01500206, 0.0177716 , 0.02105243, 0.02493894,
       0.02954293, 0.03499688, 0.04145769, 0.04911122, 0.05817769]) # Theta array

# %%
covariance = cov.compute_cov_noise(
    thtdata,
    rows=7, #rows, diagonals and dimension are in order to add a mask
    diagonals=4,
    dim=20,
    m=2, #multipole 1 
    mp=2, #multipole 2 
    noise=6.1e-11, #add noise
    output_file="analytic_covariance_22_noise.txt" #if you don't want to save the output just put None
)
# Out:
# Progress: 0/45
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 covariance = cov.compute_cov_noise(
#       2     thtdata,
#       3     rows=7, #rows, diagonals and dimension are in order to add a mask
#       4     diagonals=4,
#       5     dim=20,
#       6     m=2, #multipole 1
#       7     mp=2, #multipole 2
#       8     noise=6.1e-11, #add noise
#       9     output_file="analytic_covariance_22_noise.txt" #if you don't want to save the output just put None
#      10 )
#
# File ~/Research/Codigos/NagBody_pkg/NagBody_sources/perturbations/wlcov/wlcov/tests/notebooks/AnalyticalCov.py:145, in compute_cov_noise(thtdata, rows, diagonals, dim, m, mp, ppp, noise, input_file, temp_file, program, output_file)
#     142 th1, th2 = thtdata[idx1]
#     143 th1p, th2p = thtdata[idx2]
# --> 145 val = calculate_integral(
#     146     th1, th2, th1p, th2p,
#     147     m, mp, ppp,
#     148     temp_file,
#     149     program)
#     151 cov[i, j] = val
#     152 cov[j, i] = val
#
# File ~/Research/Codigos/NagBody_pkg/NagBody_sources/perturbations/wlcov/wlcov/tests/notebooks/AnalyticalCov.py:74, in calculate_integral(theta1, theta2, thetap1, thetap2, m, mp, ppp, inputfile, program)
#      59 def calculate_integral(theta1, theta2, thetap1, thetap2,
#      60                        m, mp, ppp, inputfile, program="./IntegralCovMatrix"):
#      62     args = [
#      63         program,
#      64         f"theta1={theta1}",
#    (...)     71         f"inputfile={inputfile}"
#      72     ]
# ---> 74     return _run_integral(args)
#
# File ~/Research/Codigos/NagBody_pkg/NagBody_sources/perturbations/wlcov/wlcov/tests/notebooks/AnalyticalCov.py:34, in _run_integral(args, verbose)
#      32 def _run_integral(args, verbose=False):
#      33     try:
# ---> 34         result = subprocess.run(args, check=True, capture_output=True, text=True)
#      36         if verbose:
#      37             print(result.stdout)
#
# File /opt/homebrew/anaconda3/envs/class-env312/lib/python3.12/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /opt/homebrew/anaconda3/envs/class-env312/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/homebrew/anaconda3/envs/class-env312/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: './IntegralCovMatrix'

# %%
plt.figure(figsize=(6,5))
plt.imshow(np.log10(abs(covariance)))
plt.colorbar(label="Covariance")
plt.title("Covariance Matrix")
plt.xlabel("Index")
plt.ylabel("Index")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize=(6,5))
# ----> 2 plt.imshow(np.log10(abs(covariance)))
#       3 plt.colorbar(label="Covariance")
#       4 plt.title("Covariance Matrix")
#
# NameError: name 'covariance' is not defined
